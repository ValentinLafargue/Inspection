# %% [markdown]
# # Preparation

# %% [markdown]
# ## Import

# %% [markdown]
# https://github.com/socialfoundations/folktables/tree/main

# %%
import sys
sys.path.append("../src")

from utils import *
from mitigation_fct import *
from distance import *
from Gems_Wasserstein import *

# %%
import pandas as pd
import torch
import torch.nn as nn
import schedulefree
import numpy as np
import matplotlib.pyplot as plt
import math
from tqdm import tqdm
from scipy import stats

# %%
dic_file = {
    'INC' : {
        'path' : '../Data/ASCIncome_2023.csv',
        'S_variable_name' : 'SEX',
        'target_name' : 'PINCP',
        'threshold' : 125000,
        'S_fct' : lambda S : 2 - S,
    },
    'TRA' : {
        'path' : '../Data/ACSTravelTime_2023.csv',
        'S_variable_name' : 'SEX',
        'target_name' : 'JWMNP',
        'threshold' : 25,
        'S_fct' : lambda S : 2 - S,
    },
    'MOB' : {
        'path' : '../Data/ACSMobility_2023.csv',
        'S_variable_name' : 'AGEP',
        'target_name' : 'MIG',
        'threshold' : 0.5,
        'S_fct' : lambda S : S > 25,
    },
    'EMP' : {
        'path' : '../Data/ACSEmploymentFiltered_2023.csv',
        'S_variable_name' : 'DIS',
        'target_name' : 'ESR',
        'threshold' : 0.5,
        'S_fct' : lambda S : S - 1,
    },
    'PUC' : {
        'path' : '../Data/ACSPublicCoverage_2023.csv',
        'S_variable_name' : 'DIS',
        'target_name' : 'PUBCOV',
        'threshold' : 0.5,
        'S_fct' : lambda S : 2 - S,
    },
}

# %% [markdown]
# ## Pre-processing

# %%
file_obj = 'MOB'
result_path = '../Result/ASC_' + file_obj + '/'

# %%
#df_all = pd.read_csv('../Data/ASCIncome_2023.csv')
df_all = pd.read_csv(dic_file[file_obj]['path'])
try:
    #variable always equal to the same value
    df_all = df_all.drop('ESP', axis = 1)
except:
    ''

# %%
X_col, dic_col_name_index = [], {}
for index, column in enumerate(df_all.columns):
    if column not in [dic_file[file_obj]['target_name'], dic_file[file_obj]['S_variable_name']]:
        X_col.append(column)
    dic_col_name_index[column] = index

# %%
test_percentage = 0.2# 0.05
epochs, batch_size = 3, 2048
X = df_all[X_col].values
X_cr = (X - X.mean(axis = 0)) / (X.var(axis = 0) ** (1/2))
Y = df_all[dic_file[file_obj]['target_name']].values
S = df_all[dic_file[file_obj]['S_variable_name']].values

test_size = int(len(X) * test_percentage)
train_size = len(X) - test_size
train_size
# Out:
# 2188379

# %%
seed = 1234
indexs = np.arange(len(X))
np.random.seed(seed)
np.random.shuffle(indexs)
X_cr_train, Y_train, S_train = X_cr[indexs[:train_size]], Y[indexs[:train_size]], S[indexs[:train_size]]
X_cr_test, Y_test, S_test    = X_cr[indexs[train_size:]], Y[indexs[train_size:]], S[indexs[train_size:]]

X_train, X_test, Y_train, Y_test = torch.from_numpy(X_cr_train.astype(np.float32)), torch.from_numpy(X_cr_test.astype(np.float32)), torch.from_numpy(Y_train.astype(np.float32)), torch.from_numpy(Y_test.astype(np.float32))

# %%
threshold = dic_file[file_obj]['threshold']

# %%
model = Network(X_train.shape[1], 
                activation_bool = True, 
                n_nodes=256, 
                n_loop = 2)

optimizer = schedulefree.AdamWScheduleFree(model.parameters(), 
                                           lr=0.001) #torch.optim.AdamW(model.parameters(), lr = 0.001)
net_path = result_path + 'net_state_dic.pt'
'''
training_network_threshold(model, 
                           optimizer, 
                           threshold=threshold, 
                           X_train    = X_train,
                           Y_train    = Y_train,
                           X_test     = X_test,
                           Y_test     = Y_test,
                           epochs     = 1,
                           batch_size = batch_size,
                           )

torch.save(model.state_dict(), net_path)
'''
model.load_state_dict(torch.load(net_path, weights_only=True))
model.eval()
# Out:
# Network(
#   (seq): Sequential(
#     (0): BatchNorm1d(19, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Linear(in_features=19, out_features=256, bias=True)
#     (2): ReLU()
#     (3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Linear(in_features=256, out_features=256, bias=True)
#     (5): ReLU()
#     (6): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Linear(in_features=256, out_features=256, bias=True)
#     (8): ReLU()
#     (9): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): Linear(in_features=256, out_features=1, bias=True)
#   )
#   (activation): Sigmoid()
# )

# %% [markdown]
# test result

# %%
label = (Y_test > threshold)*1.
proba = model(X_test.float()).squeeze()
prob_threshold = np.quantile(proba.detach().numpy(),  1 - ((Y_train > threshold)*1.).mean()) - 1e-7
pred = ( proba > prob_threshold)*1.
#pred = (model(X_test.float()).squeeze() > 0.5)*1.
acc = ( (pred == label)*1.).mean().item()
number_expe = 20000
inputs, groups = X_test[:number_expe].clone(), dic_file[file_obj]['S_fct'](S_test[:number_expe].copy())
DI = (pred[:number_expe][groups==0].mean() / pred[:number_expe][groups==1].mean()).item()
print(f'pred mean : {np.round(pred.mean().item(), 3)}, with an accuracy of {np.round(acc,3)}, and the Disparate Impact is {np.round(DI,3)}')
# Out:
# pred mean : 0.888, with an accuracy of 0.845, and the Disparate Impact is 0.46

# %%
np.save(file = result_path + 'Grad_la_nu.npy',
        arr = arr_grad_la_nu)

# %% [markdown]
# # Mitigation

# %%
stresser = Stresser(X = inputs.float().numpy(), S = groups)

# %%
stresser.W.DI_miti_grad(model,
                        prob_threshold = prob_threshold,
                        threshold = 0.8,
                        threshold_augm_constr = 0.005,
                        threshold_lr_cdt = 0.1,
                        iteration_threshold = 200,
                        look_alike = False,
                        verbose = True,
                        CONSTR_REGU = 0.3,
                        lr = 0.1,
                        delta_type = 'mean'
                        )
t_reg_me = stresser.W.t
stresser.W.DI_miti_grad(model,
                        prob_threshold = prob_threshold,
                        threshold = 0.8,
                        threshold_augm_constr = 0.005,
                        threshold_lr_cdt = 0.1,
                        iteration_threshold = 200,
                        look_alike = False,
                        verbose = False,
                        CONSTR_REGU = 0.3,
                        lr = 0.1,
                        delta_type = 'num'
                        )
t_reg_nu = stresser.W.t
stresser.W.DI_miti_grad(model,
                        prob_threshold = prob_threshold,
                        threshold = 0.8,
                        threshold_augm_constr = 0.005,
                        threshold_lr_cdt = 0.1,
                        iteration_threshold = 200,
                        look_alike = True,
                        verbose = False,
                        CONSTR_REGU = 0.3,
                        lr = 0.1,
                        delta_type = 'mean'
                        )
t_la_me = stresser.W.t
stresser.W.DI_miti_grad(model,
                        prob_threshold = prob_threshold,
                        threshold = 0.8,
                        threshold_augm_constr = 0.005,
                        threshold_lr_cdt = 0.1,
                        iteration_threshold = 200,
                        look_alike = True,
                        verbose = False,
                        CONSTR_REGU = 0.1,
                        lr = 0.1,
                        delta_type = 'num'
                        )
t_la_nu = stresser.W.t
# Out:
# P(Y=1|S=0) = 0.2423, P(Y=1|S=1) = 0.7663
# former DI is 0.316, we thus have a difference of 0.484 to mitigate
# We want to change it to new_P(Y=1|S=0) = 0.4483, and new_P(Y=1|S=1) = 0.5603
# 0.2718462316262054 0.7312000758385233
# the starting mean is 0.0, we are 0.272 away
# Thus the direction is 1.0
#
# 0
# the contraint value is 0.25539
# the euclidian distance between is 0.0001257729163626209,
#
# 1
# the contraint value is 0.24279
# the euclidian distance between is 0.00041885662358254194,
#
# 2
# the contraint value is 0.23108
# the euclidian distance between is 0.0007932198932394385,
#
# 3
# the contraint value is 0.22048
# the euclidian distance between is 0.0011948085157200694,
#
# 4
# the contraint value is 0.21222
# the euclidian distance between is 0.0015941844321787357,
#
# 5
# the contraint value is 0.20451
# the euclidian distance between is 0.0019735880196094513,
#
# 6
# the contraint value is 0.19793
# the euclidian distance between is 0.0023226740304380655,
#
# 7
# the contraint value is 0.19111
# the euclidian distance between is 0.0026378710754215717,
#
# 8
# the former constraint was equal to 0.19111, the new is 0.18734
# the regularization constraint increased to 0.36
# the contraint value is 0.18734
# the euclidian distance between is 0.0,
#
# 9
# the former constraint was equal to 0.18734, the new is 0.27185
# the regularization constraint increased to 0.432
# the contraint value is 0.27185
# the euclidian distance between is 0.0,
#
# 10
# the contraint value is 0.24857
# the euclidian distance between is 0.0002660194877535105,
#
# 11
# the contraint value is 0.22931
# the euclidian distance between is 0.0008814287139102817,
#
# 12
# the contraint value is 0.21125
# the euclidian distance between is 0.0016632016049697995,
#
# 13
# the contraint value is 0.19504
# the euclidian distance between is 0.002501562237739563,
#
# 14
# the contraint value is 0.18108
# the euclidian distance between is 0.003326989710330963,
#
# 15
# the contraint value is 0.16936
# the euclidian distance between is 0.004103401210159063,
#
# 16
# the contraint value is 0.15868
# the euclidian distance between is 0.004817378707230091,
#
# 17
# the contraint value is 0.14962
# the euclidian distance between is 0.005462672095745802,
#
# 18
# the contraint value is 0.14223
# the euclidian distance between is 0.006040000822395086,
#
# 19
# the contraint value is 0.13525
# the euclidian distance between is 0.006549972575157881,
#
# 20
# the contraint value is 0.12979
# the euclidian distance between is 0.007000883109867573,
#
# 21
# the former constraint was equal to 0.12979, the new is 0.12618
# the regularization constraint increased to 0.5184
# the contraint value is 0.12618
# the euclidian distance between is 0.0,
#
# 22
# the former constraint was equal to 0.12618, the new is 0.27185
# the regularization constraint increased to 0.62208
# the contraint value is 0.27185
# the euclidian distance between is 0.0,
#
# 23
# the contraint value is 0.23886
# the euclidian distance between is 0.0005679337773472071,
#
# 24
# the contraint value is 0.20836
# the euclidian distance between is 0.0018698298372328281,
#
# 25
# the contraint value is 0.17995
# the euclidian distance between is 0.003506346605718136,
#
# 26
# the contraint value is 0.15403
# the euclidian distance between is 0.005221840925514698,
#
# 27
# the contraint value is 0.1322
# the euclidian distance between is 0.006893920712172985,
#
# 28
# the contraint value is 0.11583
# the euclidian distance between is 0.008454062044620514,
#
# 29
# the contraint value is 0.09785
# the euclidian distance between is 0.009887805208563805,
#
# 30
# the contraint value is 0.08405
# the euclidian distance between is 0.011160505935549736,
#
# 31
# the contraint value is 0.07024
# the euclidian distance between is 0.012287099845707417,
#
# 32
# the contraint value is 0.06117
# the euclidian distance between is 0.013266841880977154,
#
# 33
# the contraint value is 0.05226
# the euclidian distance between is 0.014129798859357834,
#
# 34
# the contraint value is 0.04576
# the euclidian distance between is 0.014883455820381641,
#
# 35
# the contraint value is 0.0387
# the euclidian distance between is 0.015547435730695724,
#
# 36
# the contraint value is 0.03212
# the euclidian distance between is 0.016125593334436417,
#
# 37
# the former constraint was equal to 0.03212, the new is 0.02738
# the regularization constraint increased to 0.7465
# the contraint value is 0.02738
# the euclidian distance between is 0.0,
#
# 38
# the former constraint was equal to 0.02738, the new is 0.27185
# the regularization constraint increased to 0.8958
# the contraint value is 0.27185
# the euclidian distance between is 0.0,
#
# 39
# the contraint value is 0.22217
# the euclidian distance between is 0.001226993277668953,
#
# 40
# the contraint value is 0.17441
# the euclidian distance between is 0.00398462126031518,
#
# 41
# the contraint value is 0.12979
# the euclidian distance between is 0.007328682579100132,
#
# 42
# the contraint value is 0.09239
# the euclidian distance between is 0.01075655221939087,
#
# 43
# the contraint value is 0.05796
# the euclidian distance between is 0.013993424363434315,
#
# 44
# the contraint value is 0.02915
# the euclidian distance between is 0.016888730227947235,
#
# 45
# the contraint value is 0.00652
# the euclidian distance between is 0.01946166716516018,
#
# 46
# tensor(-0.0182)
# 0.29004815220832825 0.2718462316262054 0.27191011235955054
# the starting mean is 1.0, we are 0.269 away
# Thus the direction is -1.0
#
# 0
# the contraint value is 0.25632
# the euclidian distance between is 0.00016421284817624837,
#
# 1
# the contraint value is 0.24752
# the euclidian distance between is 0.0005444595590233803,
#
# 2
# the contraint value is 0.23871
# the euclidian distance between is 0.0010271506616845727,
#
# 3
# the contraint value is 0.23284
# the euclidian distance between is 0.0015399075346067548,
#
# 4
# the contraint value is 0.22733
# the euclidian distance between is 0.0020451464224606752,
#
# 5
# the contraint value is 0.22036
# the euclidian distance between is 0.0025189020670950413,
#
# 6
# the former constraint was equal to 0.22036, the new is 0.21779
# the regularization constraint increased to 0.36
# the contraint value is 0.21779
# the euclidian distance between is 0.0,
#
# 7
# the former constraint was equal to 0.21779, the new is 0.2688
# the regularization constraint increased to 0.432
# the contraint value is 0.2688
# the euclidian distance between is 0.0,
#
# 8
# the contraint value is 0.25119
# the euclidian distance between is 0.00034206954296678305,
#
# 9
# the contraint value is 0.23797
# the euclidian distance between is 0.0011285068467259407,
#
# 10
# the contraint value is 0.2266
# the euclidian distance between is 0.002118381205946207,
#
# 11
# the contraint value is 0.21669
# the euclidian distance between is 0.0031660646200180054,
#
# 12
# the contraint value is 0.20531
# the euclidian distance between is 0.0041874367743730545,
#
# 13
# the contraint value is 0.19687
# the euclidian distance between is 0.005137932021170855,
#
# 14
# the contraint value is 0.1899
# the euclidian distance between is 0.005998461041599512,
#
# 15
# the former constraint was equal to 0.1899, the new is 0.18586
# the regularization constraint increased to 0.5184
# the contraint value is 0.18586
# the euclidian distance between is 0.0,
#
# 16
# the former constraint was equal to 0.18586, the new is 0.2688
# the regularization constraint increased to 0.62208
# the contraint value is 0.2688
# the euclidian distance between is 0.0,
#
# 17
# the contraint value is 0.24495
# the euclidian distance between is 0.0007121808594092727,
#
# 18
# the contraint value is 0.2233
# the euclidian distance between is 0.0023385619278997183,
#
# 19
# the contraint value is 0.20458
# the euclidian distance between is 0.004348786547780037,
#
# 20
# the contraint value is 0.18733
# the euclidian distance between is 0.006447820458561182,
#
# 21
# the contraint value is 0.17082
# the euclidian distance between is 0.008469869382679462,
#
# 22
# the contraint value is 0.15761
# the euclidian distance between is 0.010338830761611462,
#
# 23
# the contraint value is 0.1455
# the euclidian distance between is 0.012022390030324459,
#
# 24
# the contraint value is 0.13596
# the euclidian distance between is 0.01351882517337799,
#
# 25
# the contraint value is 0.13082
# the euclidian distance between is 0.014829603023827076,
#
# 26
# the former constraint was equal to 0.13082, the new is 0.12605
# the regularization constraint increased to 0.7465
# the contraint value is 0.12605
# the euclidian distance between is 0.0,
#
# 27
# the former constraint was equal to 0.12605, the new is 0.2688
# the regularization constraint increased to 0.8958
# the contraint value is 0.2688
# the euclidian distance between is 0.0,
#
# 28
# the contraint value is 0.23577
# the euclidian distance between is 0.0014885603450238705,
#
# 29
# the contraint value is 0.20054
# the euclidian distance between is 0.00482883770018816,
#
# 30
# the contraint value is 0.16862
# the euclidian distance between is 0.008850964717566967,
#
# 31
# the contraint value is 0.13816
# the euclidian distance between is 0.012959951534867287,
#
# 32
# the contraint value is 0.12091
# the euclidian distance between is 0.01684996485710144,
#
# 33
# the contraint value is 0.10036
# the euclidian distance between is 0.020425695925951004,
#
# 34
# the contraint value is 0.08531
# the euclidian distance between is 0.023589476943016052,
#
# 35
# the contraint value is 0.0743
# the euclidian distance between is 0.026377655565738678,
#
# 36
# the contraint value is 0.0644
# the euclidian distance between is 0.028828859329223633,
#
# 37
# the contraint value is 0.05816
# the euclidian distance between is 0.03096536546945572,
#
# 38
# the former constraint was equal to 0.05816, the new is 0.05339
# the regularization constraint increased to 1.07495
# the contraint value is 0.05339
# the euclidian distance between is 0.0,
#
# 39
# the former constraint was equal to 0.05339, the new is 0.2688
# the regularization constraint increased to 1.28995
# the contraint value is 0.2688
# the euclidian distance between is 0.0,
#
# 40
# the contraint value is 0.21816
# the euclidian distance between is 0.0031174751929938793,
#
# 41
# the contraint value is 0.16274
# the euclidian distance between is 0.009838705882430077,
#
# 42
# the contraint value is 0.11761
# the euclidian distance between is 0.017681395635008812,
#
# 43
# the contraint value is 0.07797
# the euclidian distance between is 0.025441497564315796,
#
# 44
# the contraint value is 0.05192
# the euclidian distance between is 0.03258933871984482,
#
# 45
# the contraint value is 0.0244
# the euclidian distance between is 0.03903541713953018,
#
# 46
# tensor(-0.0017)
# 0.7295413017272949 0.7312000758385233 0.2689908256880734

# %%
pred_ori = (model(torch.tensor(stresser.X).type(torch.float32)) > prob_threshold)*1.

tensor_reg_me = (torch.from_numpy(t_reg_me + stresser.X)).type(torch.float32)
pred_reg_me = (model(tensor_reg_me) > prob_threshold)*1.

tensor_reg_nu = (torch.from_numpy(t_reg_nu + stresser.X)).type(torch.float32)
pred_reg_nu = (model(tensor_reg_nu) > prob_threshold)*1.

tensor_la_me = (torch.from_numpy(t_la_me + stresser.X)).type(torch.float32)
pred_la_me = (model(tensor_la_me) > prob_threshold)*1.

tensor_la_nu = (torch.from_numpy(t_la_nu + stresser.X)).type(torch.float32)
pred_la_nu = (model(tensor_la_nu) > prob_threshold)*1.

# %%
arr_start       = np.concatenate([stresser.X, stresser.S.reshape(number_expe, -1), pred_ori], axis = 1)

arr_grad_reg_me = np.concatenate([stresser.X + t_reg_me, stresser.S.reshape(number_expe, -1), pred_reg_me], axis = 1)
arr_grad_reg_nu = np.concatenate([stresser.X + t_reg_nu, stresser.S.reshape(number_expe, -1), pred_reg_nu], axis = 1)

arr_grad_la_me  = np.concatenate([stresser.X + t_la_me, stresser.S.reshape(number_expe, -1), pred_la_me], axis = 1)
arr_grad_la_nu  = np.concatenate([stresser.X + t_la_nu, stresser.S.reshape(number_expe, -1), pred_la_nu], axis = 1)

# %%
new_arr_mod_SF, bins, translation = find_translation_DI(arr = arr_start,
                                                        S_index = -2,
                                                        Y_index = -1,
                                                        threshold = 0.8,
                                                        speed = 1,
                                                        bool_return_all = True,
                                                        verbose = False
                                                        )

# %%
new_arr, swaps, dic_number_swap_done, wass_distance = find_sampling_wasserstein_DI(arr = arr_start,
                                                                                   S_index = -2, #dic_col_name_index[dic_file[file_obj]['S_variable_name']],
                                                                                   Y_index = -1, #dic_col_name_index[dic_file[file_obj]['target_name']],
                                                                                   verbose = False,
                                                                                   )

# %%
arr_miti_gems_KL_number = Gems_fair_mitigation_arr(arr=arr_start, 
                                                   S_column_index = -2,
                                                   Pred_column_index = -1, 
                                                   Y_column_index = None,
                                                   DI_target = 0.8,
                                                   delta_type = 'number')

arr_miti_gems_KL_mean = Gems_fair_mitigation_arr(arr=arr_start, 
                                                 S_column_index = -2,
                                                 Pred_column_index = -1, 
                                                 Y_column_index = None,
                                                 DI_target = 0.8,
                                                 delta_type = 'mean')

# %%
np.save(file = result_path + 'DI.npy',
        arr  = DI)
np.save(file = result_path + 'X_number_column.npy',
        arr  = X_train.shape[1])
np.save(file = result_path + 'threshold.npy',
        arr  = prob_threshold)
np.save(file = result_path + 'original.npy', 
        arr = arr_start)

np.save(file = result_path + 'Grad_reg_me.npy',
        arr = arr_grad_reg_me)
np.save(file = result_path + 'Grad_reg_nu.npy',
        arr = arr_grad_reg_nu)
np.save(file = result_path + 'Grad_la_me.npy',
        arr = arr_grad_la_me)
np.save(file = result_path + 'Grad_la_nu.npy',
        arr = arr_grad_la_nu)


np.save(file = result_path + 'Miti_sampling_X.npy', 
        arr = new_arr)
np.save(file = result_path + 'Miti_mod_SF.npy', 
        arr = new_arr_mod_SF)
np.save(file = result_path + 'Miti_Gems_number.npy', 
        arr = arr_miti_gems_KL_number)
np.save(file = result_path + 'Miti_Gems_mean.npy', 
        arr = arr_miti_gems_KL_mean)
